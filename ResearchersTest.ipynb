# %%
# Test Notebook for JupyterLite Library Availability

# --- NumPy ---
try:
    import numpy as np
    print(f"NumPy version: {np.__version__}")
    arr = np.array([1, 2, 3])
    print(f"NumPy array multiplied by 2: {arr * 2}")
except ImportError as e:
    print(f"NumPy import error: {e}")

# --- Pandas ---
try:
    import pandas as pd
    print(f"Pandas version: {pd.__version__}")
    data = {'col1': [1, 2], 'col2': [3, 4]}
    df = pd.DataFrame(data)
    print("Pandas DataFrame head:")
    print(df.head())
except ImportError as e:
    print(f"Pandas import error: {e}")

# --- Matplotlib ---
try:
    import matplotlib
    print(f"Matplotlib version: {matplotlib.__version__}")
    import matplotlib.pyplot as plt
    plt.plot([1, 2, 3], [4, 5, 6])
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    plt.title("Simple Plot")
    plt.show() # May or may not display correctly within JupyterLite
except ImportError as e:
    print(f"Matplotlib import error: {e}")

# --- SciPy ---
try:
    import scipy
    print(f"SciPy version: {scipy.__version__}")
    import scipy.constants
    print(f"SciPy constant pi: {scipy.constants.pi}")
except ImportError as e:
    print(f"SciPy import error: {e}")

# --- Scikit-learn ---
try:
    import sklearn
    print(f"Scikit-learn version: {sklearn.__version__}")
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    print(f"Scikit-learn LinearRegression model: {model}")
except ImportError as e:
    print(f"Scikit-learn import error: {e}")
# Out:
# NumPy version: 2.0.2
# NumPy array multiplied by 2: [2 4 6]
# Pandas version: 2.2.3
# Pandas DataFrame head:
#    col1  col2
# 0     1     3
# 1     2     4
# Matplotlib version: 3.8.4
# Matplotlib is building the font cache; this may take a moment.
# SciPy version: 1.14.1
# SciPy constant pi: 3.141592653589793
# Scikit-learn version: 1.5.2
# Scikit-learn LinearRegression model: LinearRegression()
# Jupyter import error: No module named 'jupyter'. May not indicate a problem if other tests work.
